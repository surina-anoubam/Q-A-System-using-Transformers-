# %%
# !pip install -q transformers

# %%
from transformers import pipeline
import pandas as pd

# %%
import torch
torch.__version__
# Out:
# '2.1.0+cu121'

# %%
# !pip install torch-scatter -f https://pytorch-geometric.com/whl/torch-1.6.0+cu102.html
# Out:
# Looking in links: https://pytorch-geometric.com/whl/torch-1.6.0+cu102.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# ERROR: Operation cancelled by user

# %%
tqa = pipeline(task="table-question-answering",model="google/tapas-base-finetuned-wtq")

# %%
table=pd.read_csv("/content/Articles New.csv")

# %%
table = table.astype(str)

# %%
table
# Out:
#     Unnamed: 0                           source  \
# 0            0       https://indianexpress.com/
# 1            1            https://www.ndtv.com/
# 2            2              https://thewire.in/
# 3            3            https://www.ndtv.com/
# 4            4        https://www.thehindu.com/
# ..         ...                              ...
# 568        568    https://www.outlookindia.com/
# 569        569    https://www.thehansindia.com/
# 570        570        https://www.oneindia.com/
# 571        571     https://www.indiatvnews.com/
# 572        572  https://sportstar.thehindu.com/
#
#                                               keywords  \
# 0    ['manipur rajya sabha', 'manipur', 'manipur vi...
# 1    ['manipur discussion in parliament', 'rule 267...
# 2    ['gujarat riots 2002', 'manipur video', 'top h...
# 3    ['arvind kejriwal to pm modi', 'manipur violen...
# 4    ['national news', 'parliament monsoon session ...
# ...

# %%
query = "Who has scored the highest runs?"
print(tqa(table=table,query=query)["answer"])
