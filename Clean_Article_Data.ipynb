# %%
import pandas as pd

# %%
articles = pd.read_csv('/content/articles.csv')

# %%
articles.head()
# Out:
#    S.No.                                                _id  \
# 0      0  https://indianexpress.com/article/explained/ru...
# 1      1  https://www.ndtv.com/india-news/manipur-discus...
# 2      2  https://thewire.in/politics/india-democracy-su...
# 3      3  https://www.ndtv.com/india-news/pay-attention-...
# 4      4  https://www.thehindu.com/news/national/sonia-g...
#
#                        source  \
# 0  https://indianexpress.com/
# 1       https://www.ndtv.com/
# 2         https://thewire.in/
# 3       https://www.ndtv.com/
# 4   https://www.thehindu.com/
#
#                                             keywords scrapedDate  \
# 0  ['manipur rajya sabha', 'manipur', 'manipur vi...     37:04.8
# 1  ['manipur discussion in parliament', 'rule 267...     37:39.2
# 2  ['gujarat riots 2002', 'manipur video', 'top h...     05:22.7
# 3  ['arvind kejriwal to pm modi', 'manipur violen...     05:24.4
# 4  ['national news', 'parliament monsoon session ...     05:27.0
#
# ...

# %%
articles.drop('S.No.', inplace=True, axis=1)
articles.drop('scrapedDate', inplace=True, axis=1)
articles.drop('dateModified', inplace=True, axis=1)
articles.drop('image', inplace=True, axis=1)
articles.drop('_id', inplace=True, axis=1)

# %%
articles.head()
# Out:
#                        source  \
# 0  https://indianexpress.com/
# 1       https://www.ndtv.com/
# 2         https://thewire.in/
# 3       https://www.ndtv.com/
# 4   https://www.thehindu.com/
#
#                                             keywords  \
# 0  ['manipur rajya sabha', 'manipur', 'manipur vi...
# 1  ['manipur discussion in parliament', 'rule 267...
# 2  ['gujarat riots 2002', 'manipur video', 'top h...
# 3  ['arvind kejriwal to pm modi', 'manipur violen...
# 4  ['national news', 'parliament monsoon session ...
#
#                                          articleBody  \
# 0  The opening day of the Monsoon Session of Parl...
# 1  A day after a huge ruckus over a horrific vide...
# 2  The fact that ten more ‘like-minded’ parties h...
# 3  Delhi Chief Minister Arvind Kejriwal on Wednes...
# 4  July 20, 2023 10:30 pm | Updated July 21, 2023...
#
#                                                title
# 0  Rule 176 vs Rule 267: What Govt agrees to, wha...
# ...

# %%
articles.to_csv('Articles New.csv')
